# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
global_child_mortality_data = pd.read_csv("global-child-mortality-timeseries.csv")
global_child_mortality_data.head()
# Out:
#   Entity      Code  Year  \
# 0  World  OWID_WRL  1800
# 1  World  OWID_WRL  1820
# 2  World  OWID_WRL  1840
# 3  World  OWID_WRL  1860
# 4  World  OWID_WRL  1880
#
#    Share surviving first 5 years of life (based on Gapminder and World Bank (2019))  \
# 0                                               56.7
# 1                                               57.3
# 2                                               59.6
# 3                                               58.6
# 4                                               62.0
#
#    Share dying in first 5 years (based on Gapminder and World Bank (2019))
# 0                                               43.3
# 1                                               42.7
# 2                                               40.4
# 3                                               41.4
# 4                                               38.0

# %%
print("No. of rows and columns:", global_child_mortality_data.shape)
# Out:
# No. of rows and columns: (65, 5)

# %%
duplicate_global_child_mortality_data_rows= global_child_mortality_data[global_child_mortality_data.duplicated()]
print("No. of duplicate rows:", duplicate_global_child_mortality_data_rows.shape)
global_child_mortality_data.count()
# Out:
# No. of duplicate rows: (0, 5)
# Entity                                                                              65
# Code                                                                                65
# Year                                                                                65
# Share surviving first 5 years of life (based on Gapminder and World Bank (2019))    65
# Share dying in first 5 years (based on Gapminder and World Bank (2019))             65
# dtype: int64

# %%
print(global_child_mortality_data.isnull().sum())
# Out:
# Entity                                                                              0
# Code                                                                                0
# Year                                                                                0
# Share surviving first 5 years of life (based on Gapminder and World Bank (2019))    0
# Share dying in first 5 years (based on Gapminder and World Bank (2019))             0
# dtype: int64

# %%
global_child_mortality_data= global_child_mortality_data.rename(columns={"Share surviving first 5 years of life (based on Gapminder and World Bank (2019))":"Percentage_surviving_in_first_5_years"})
global_child_mortality_data.head()
# Out:
#   Entity      Code  Year  Percentage_surviving_in_first_5_years  \
# 0  World  OWID_WRL  1800                                   56.7
# 1  World  OWID_WRL  1820                                   57.3
# 2  World  OWID_WRL  1840                                   59.6
# 3  World  OWID_WRL  1860                                   58.6
# 4  World  OWID_WRL  1880                                   62.0
#
#    Percentage_dying_in_first_5_years
# 0                               43.3
# 1                               42.7
# 2                               40.4
# 3                               41.4
# 4                               38.0

# %%
global_child_mortality_data= global_child_mortality_data.rename(columns={"Share dying in first 5 years (based on Gapminder and World Bank (2019))":"Percentage_dying_in_first_5_years"})
global_child_mortality_data.head()
# Out:
#   Entity      Code  Year  Percentage_surviving_in_first_5_years  \
# 0  World  OWID_WRL  1800                                   56.7
# 1  World  OWID_WRL  1820                                   57.3
# 2  World  OWID_WRL  1840                                   59.6
# 3  World  OWID_WRL  1860                                   58.6
# 4  World  OWID_WRL  1880                                   62.0
#
#    Percentage_dying_in_first_5_years
# 0                               43.3
# 1                               42.7
# 2                               40.4
# 3                               41.4
# 4                               38.0

# %%
fig, ax = plt.subplots(figsize= (15,10))
ax.bar(global_child_mortality_data.index, global_child_mortality_data['Percentage_surviving_in_first_5_years'], label='Percentage_surviving_in_first_5_years')
ax.bar(global_child_mortality_data.index, global_child_mortality_data['Percentage_dying_in_first_5_years'], bottom=global_child_mortality_data['Percentage_surviving_in_first_5_years'], label='Percentage_dying_in_first_5_years')
ax.set_title('Child Mortality Analysis')
ax.legend()

# %%
#This graph shows the decline in mortality over the years

# %%
Country_data = pd.read_csv("country_data.csv")
Country_data.head()
# Out:
#            Country                               Region  Population  \
# 0     Afghanistan         ASIA (EX. NEAR EAST)             31056997
# 1         Albania   EASTERN EUROPE                          3581655
# 2         Algeria   NORTHERN AFRICA                        32930091
# 3  American Samoa   OCEANIA                                   57794
# 4         Andorra   WESTERN EUROPE                            71201
#
#    Area (sq. mi.) Pop. Density (per sq. mi.) Coastline (coast/area ratio)  \
# 0          647500                       48,0                         0,00
# 1           28748                      124,6                         1,26
# 2         2381740                       13,8                         0,04
# 3             199                      290,4                        58,29
# 4             468                      152,1                         0,00
#
#   Net migration Infant mortality (per 1000 births)  GDP ($ per capita)  \
# ...

# %%
print("No. of rows and columns:", Country_data.shape)
# Out:
# No. of rows and columns: (227, 20)

# %%
duplicate_Country_data_rows= Country_data[Country_data.duplicated()]
print("No. of duplicate rows:", duplicate_Country_data_rows.shape)
Country_data.count()
# Out:
# No. of duplicate rows: (0, 20)
# Country                               227
# Region                                227
# Population                            227
# Area (sq. mi.)                        227
# Pop. Density (per sq. mi.)            227
# Coastline (coast/area ratio)          227
# Net migration                         224
# Infant mortality (per 1000 births)    224
# GDP ($ per capita)                    226
# Literacy (%)                          209
# Phones (per 1000)                     223
# Arable (%)                            225
# Crops (%)                             225
# Other (%)                             225
# Climate                               205
# Birthrate                             224
# Deathrate                             223
# Agriculture                           212
# Industry                              211
# Service                               212
# dtype: int64

# %%
print(Country_data.isnull().sum())
# Out:
# Country                                0
# Region                                 0
# Population                             0
# Area (sq. mi.)                         0
# Pop. Density (per sq. mi.)             0
# Coastline (coast/area ratio)           0
# Net migration                          3
# Infant mortality (per 1000 births)     3
# GDP ($ per capita)                     1
# Literacy (%)                          18
# Phones (per 1000)                      4
# Arable (%)                             2
# Crops (%)                              2
# Other (%)                              2
# Climate                               22
# Birthrate                              3
# Deathrate                              4
# Agriculture                           15
# Industry                              16
# Service                               15
# dtype: int64

# %%
Country_data_new = Country_data.drop(['Region', 'Population', 'Area (sq. mi.)', 'Pop. Density (per sq. mi.)', 'Coastline (coast/area ratio)', 'Net migration', 'Literacy (%)', 'Phones (per 1000)', 'Arable (%)', 'Crops (%)', 'Other (%)', 'Climate', 'Birthrate', 'Deathrate', 'Agriculture', 'Industry', 'Service'], axis=1)
Country_data_new.head()
# Out:
#            Country Infant mortality (per 1000 births)  GDP ($ per capita)
# 0     Afghanistan                              163,07               700.0
# 1         Albania                               21,52              4500.0
# 2         Algeria                                  31              6000.0
# 3  American Samoa                                9,27              8000.0
# 4         Andorra                                4,05             19000.0

# %%
Country_data_new.dtypes
# Out:
# Country                                object
# Infant mortality (per 1000 births)     object
# GDP ($ per capita)                    float64
# dtype: object

# %%
Country_data_new['Infant mortality (per 1000 births)'] = Country_data_new['Infant mortality (per 1000 births)'].str.replace(',', '.')
Country_data_new = Country_data_new.astype({'Infant mortality (per 1000 births)': np.float})
Country_data_new.head()
# Out:
#            Country  Infant mortality (per 1000 births)  GDP ($ per capita)
# 0     Afghanistan                               163.07               700.0
# 1         Albania                                21.52              4500.0
# 2         Algeria                                31.00              6000.0
# 3  American Samoa                                 9.27              8000.0
# 4         Andorra                                 4.05             19000.0

# %%
Country_data_new.dtypes
# Out:
# Country                                object
# Infant mortality (per 1000 births)    float64
# GDP ($ per capita)                    float64
# dtype: object

# %%
Country_data_new1= Country_data_new.dropna(subset=["Infant mortality (per 1000 births)","GDP ($ per capita)"])
Country_data_new1.head()
# Out:
#            Country  Infant mortality (per 1000 births)  GDP ($ per capita)
# 0     Afghanistan                               163.07               700.0
# 1         Albania                                21.52              4500.0
# 2         Algeria                                31.00              6000.0
# 3  American Samoa                                 9.27              8000.0
# 4         Andorra                                 4.05             19000.0

# %%
#Sorting the Infant Mortality column into descending order and using cmap to highlight the contrast in Infant mortality and Gdp of different countries

Country_data_new1= Country_data_new1.sort_values(by="Infant mortality (per 1000 births)", ascending=False)
Country_data_new1.style.background_gradient(cmap='Oranges')
# Out:
# <style  type="text/css" >
# #T_fc217f3d_adb1_11eb_aefb_effa64ccd563row0_col1,#T_fc217f3d_adb1_11eb_aefb_effa64ccd563row200_col2{
#             background-color:  #7f2704;
#             color:  #f1f1f1;
# ...

# %%
#The above cmap shows the contrast between the Infant mortality and the GDP of different countries.

plt.rcParams['figure.figsize'] = [15,8]
Scatter_plot_for_mortality= Country_data_new1.plot.scatter(x="GDP ($ per capita)", y="Infant mortality (per 1000 births)")
plt.title('Contrast between the Infant mortality and the GDP of different countries')
# Out:
# Text(0.5, 1.0, 'Contrast between the Infant mortality and the GDP of different countries')

# %%
Country_data_new1['Infant mortality (per 1000 births)'].corr(Country_data_new1['GDP ($ per capita)'])
# Out:
# -0.6007739662612174

# %%
#The negative correlation shows that large values of Infant Mortality correspond to small values of the GDP, and vice versa.

# %%
Causes_of_death= pd.read_csv("causes-of-death-in-children.csv")
Causes_of_death.head()
# Out:
#         Entity Code  Year  \
# 0  Afghanistan  AFG  1990
# 1  Afghanistan  AFG  1991
# 2  Afghanistan  AFG  1992
# 3  Afghanistan  AFG  1993
# 4  Afghanistan  AFG  1994
#
#    Deaths - Malaria - Sex: Both - Age: Under 5 (Number)  \
# 0                                         117.787829
# 1                                         123.219140
# 2                                         125.663504
# 3                                         155.203295
# 4                                         198.951854
#
#    Deaths - HIV/AIDS - Sex: Both - Age: Under 5 (Number)  \
# 0                                           7.498654
# 1                                           8.965332
# 2                                          12.993281
# 3                                          17.952750
# 4                                          21.288766
#
#    Deaths - Neonatal preterm birth complications - Sex: Both - Age: Under 5 (Number)  \
# 0                                        8483.408122
# ...

# %%
Causes_of_death.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6468 entries, 0 to 6467
# Data columns (total 19 columns):
#  #   Column                                                                                                 Non-Null Count  Dtype
# ---  ------                                                                                                 --------------  -----
#  0   Entity                                                                                                 6468 non-null   object
#  1   Code                                                                                                   5488 non-null   object
#  2   Year                                                                                                   6468 non-null   int64
#  3   Deaths - Malaria - Sex: Both - Age: Under 5 (Number)                                                   6468 non-null   float64
# ...

# %%
#Checking missing values using Data Visualizations

sns.heatmap(Causes_of_death.isnull(), cbar=False, yticklabels=False, cmap='viridis')
# Out:
# <AxesSubplot:>

# %%
Causes_of_death = Causes_of_death[Causes_of_death['Entity']== 'World']
Causes_of_death.head()
# Out:
#      Entity      Code  Year  \
# 6356  World  OWID_WRL  1990
# 6357  World  OWID_WRL  1991
# 6358  World  OWID_WRL  1992
# 6359  World  OWID_WRL  1993
# 6360  World  OWID_WRL  1994
#
#       Deaths - Malaria - Sex: Both - Age: Under 5 (Number)  \
# 6356                                      459360.818270
# 6357                                      471995.514454
# 6358                                      483007.854186
# 6359                                      494754.481991
# 6360                                      503044.443154
#
#       Deaths - HIV/AIDS - Sex: Both - Age: Under 5 (Number)  \
# 6356                                       67450.613070
# 6357                                       84241.475721
# 6358                                      102401.993971
# 6359                                      121547.445621
# 6360                                      140641.060531
#
#       Deaths - Neonatal preterm birth complications - Sex: Both - Age: Under 5 (Number)  \
# ...

# %%
#Creating multiple line plot for plotting all the deaths due to various diseases over the years

plt.rcParams['figure.figsize'] = [18,14]
plt.plot( 'Year', 'Deaths - Malaria - Sex: Both - Age: Under 5 (Number)', data= Causes_of_death, color='red')
plt.plot( 'Year', 'Deaths - HIV/AIDS - Sex: Both - Age: Under 5 (Number)', data= Causes_of_death, color='skyblue')
plt.plot( 'Year', 'Deaths - Neonatal preterm birth complications - Sex: Both - Age: Under 5 (Number)', data= Causes_of_death, color='violet')
plt.plot( 'Year', 'Deaths - Whooping cough - Sex: Both - Age: Under 5 (Number)', data= Causes_of_death, color='pink')
plt.plot( 'Year', 'Deaths - Lower respiratory infections - Sex: Both - Age: Under 5 (Number)', data= Causes_of_death, color='orange')
plt.plot( 'Year', 'Deaths - Congenital birth defects - Sex: Both - Age: Under 5 (Number)', data= Causes_of_death, color='black')
plt.plot( 'Year', 'Deaths - Measles - Sex: Both - Age: Under 5 (Number)', data= Causes_of_death, color='coral')
plt.plot( 'Year', 'Deaths - Neonatal sepsis and other neonatal infections - Sex: Both - Age: Under 5 (Number)', data= Causes_of_death, color='tan')
plt.plot( 'Year', 'Deaths - Neonatal encephalopathy due to birth asphyxia and trauma - Sex: Both - Age: Under 5 (Number)', data= Causes_of_death, color='indigo')
plt.plot( 'Year', 'Deaths - Drowning - Sex: Both - Age: Under 5 (Number)', data= Causes_of_death, color='olive')
plt.plot( 'Year', 'Deaths - Tuberculosis - Sex: Both - Age: Under 5 (Number)', data= Causes_of_death, color='maroon')
plt.plot( 'Year', 'Deaths - Diarrheal diseases - Sex: Both - Age: Under 5 (Number)', data= Causes_of_death, color='green')
plt.plot( 'Year', 'Deaths - Neoplasms - Sex: Both - Age: Under 5 (Number)', data= Causes_of_death, color='magenta')
plt.plot( 'Year', 'Deaths - Meningitis - Sex: Both - Age: Under 5 (Number)', data= Causes_of_death, color='purple')
plt.plot( 'Year', 'Deaths - Nutritional deficiencies - Sex: Both - Age: Under 5 (Number)', data= Causes_of_death, color='teal')
plt.plot( 'Year', 'Deaths - Other neonatal disorders - Sex: Both - Age: Under 5 (Number)', data= Causes_of_death, color='crimson')
plt.title("Deaths under the age 5 due to various diseases over the years")
plt.xlabel('Year') 
plt.ylabel('No. of deaths') 
plt.legend()
plt.show()  

#pie chart
#bubble chart

# %%
#H3: Some of the leading causes of child mortality are Pneumonia, Diarrheal Diseases, Malaria, HIV/AIDS etc.
#leading causes after experiment - Pneumonia(Lower respiratory infections), Diarrheal diseases, Neonatal preterm birth complications, Neonatal encephalopathy due to birth asphyxia and trauma, Congenital birth defects 

Sum_data = Causes_of_death.sum(axis=0)
Sum_data
# Out:
# Entity                                                                                                   WorldWorldWorldWorldWorldWorldWorldWorldWorldW...
# Code                                                                                                     OWID_WRLOWID_WRLOWID_WRLOWID_WRLOWID_WRLOWID_W...
# Year                                                                                                                                                 56098
# Deaths - Malaria - Sex: Both - Age: Under 5 (Number)                                                                                           1.43968e+07
# Deaths - HIV/AIDS - Sex: Both - Age: Under 5 (Number)                                                                                          4.81931e+06
# Deaths - Neonatal preterm birth complications - Sex: Both - Age: Under 5 (Number)                                                              2.72707e+07
# ...

# %%
type(Sum_data)
# Out:
# pandas.core.series.Series

# %%
Causes_of_world_death = Sum_data.to_frame()
Causes_of_world_death
# Out:
#                                                                                                     0
# Entity                                              WorldWorldWorldWorldWorldWorldWorldWorldWorldW...
# Code                                                OWID_WRLOWID_WRLOWID_WRLOWID_WRLOWID_WRLOWID_W...
# Year                                                                                            56098
# Deaths - Malaria - Sex: Both - Age: Under 5 (Nu...                                        1.43968e+07
# Deaths - HIV/AIDS - Sex: Both - Age: Under 5 (N...                                        4.81931e+06
# Deaths - Neonatal preterm birth complications -...                                        2.72707e+07
# Deaths - Whooping cough - Sex: Both - Age: Unde...                                        3.45967e+06
# Deaths - Lower respiratory infections - Sex: Bo...                                        4.23975e+07
# ...

# %%
Causes_of_world_death.dtypes
# Out:
# 0    object
# dtype: object

# %%
#------------------------------------------------half

# %%
Dataset_1= pd.read_csv("child-deaths-igme-data.csv")
Dataset_1.head()
# Out:
#         Entity Code  Year  Number of under-five deaths
# 0  Afghanistan  AFG  1965                       159930
# 1  Afghanistan  AFG  1966                       160878
# 2  Afghanistan  AFG  1967                       161784
# 3  Afghanistan  AFG  1968                       162828
# 4  Afghanistan  AFG  1969                       163784

# %%
Dataset_2= pd.read_csv("child-mortality-1990-vs-2017-slope.csv")
Dataset_2.head()
# Out:
#         Entity      Code  Year  \
# 0     Abkhazia  OWID_ABK  2015
# 1  Afghanistan       AFG  1960
# 2  Afghanistan       AFG  1961
# 3  Afghanistan       AFG  1962
# 4  Afghanistan       AFG  1963
#
#    Mortality rate, under-5 (per 1,000 live births)  \
# 0                                              NaN
# 1                                            35.65
# 2                                            35.05
# 3                                            34.48
# 4                                            33.93
#
#    Estimates, 1950 - 2020: Total population by broad age group, both sexes combined (thousands) - Total  \
# 0                                                NaN
# 1                                           8996.967
# 2                                           9169.406
# 3                                           9351.442
# 4                                           9543.200
#
#   Continent
# 0      Asia
# 1       NaN
# 2       NaN
# 3       NaN
# 4       NaN

# %%
Merged_data_1= pd.merge(Dataset_1, Dataset_2, how='left', on=['Entity', 'Code', 'Year'])
Merged_data_1.head()
# Out:
#         Entity Code  Year  Number of under-five deaths  \
# 0  Afghanistan  AFG  1965                       159930
# 1  Afghanistan  AFG  1966                       160878
# 2  Afghanistan  AFG  1967                       161784
# 3  Afghanistan  AFG  1968                       162828
# 4  Afghanistan  AFG  1969                       163784
#
#    Mortality rate, under-5 (per 1,000 live births)  \
# 0                                            32.85
# 1                                            32.30
# 2                                            31.75
# 3                                            31.21
# 4                                            30.66
#
#    Estimates, 1950 - 2020: Total population by broad age group, both sexes combined (thousands) - Total  \
# 0                                           9956.318
# 1                                          10174.840
# 2                                          10399.936
# 3                                          10637.064
# ...

# %%
Dataset_3= pd.read_csv("child-mortality-around-the-world.csv")
Dataset_3.head()
# Out:
#         Entity Code  Year  \
# 0  Afghanistan  AFG  1950
# 1  Afghanistan  AFG  1951
# 2  Afghanistan  AFG  1952
# 3  Afghanistan  AFG  1953
# 4  Afghanistan  AFG  1954
#
#    Estimates, 1950 - 2020: Annually interpolated demographic indicators - Under-five mortality (deaths under age 5 per 1,000 live births)
# 0                                            41.6952
# 1                                            41.4045
# 2                                            40.8172
# 3                                            40.2182
# 4                                            39.6077

# %%
Merged_data_2= pd.merge(Merged_data_1, Dataset_3, how='left', on=['Entity', 'Code', 'Year'])
Merged_data_2.head()
# Out:
#         Entity Code  Year  Number of under-five deaths  \
# 0  Afghanistan  AFG  1965                       159930
# 1  Afghanistan  AFG  1966                       160878
# 2  Afghanistan  AFG  1967                       161784
# 3  Afghanistan  AFG  1968                       162828
# 4  Afghanistan  AFG  1969                       163784
#
#    Mortality rate, under-5 (per 1,000 live births)  \
# 0                                            32.85
# 1                                            32.30
# 2                                            31.75
# 3                                            31.21
# 4                                            30.66
#
#    Estimates, 1950 - 2020: Total population by broad age group, both sexes combined (thousands) - Total  \
# 0                                           9956.318
# 1                                          10174.840
# 2                                          10399.936
# 3                                          10637.064
# ...

# %%
Merged_data_2 = Merged_data_2.drop(['Mortality rate, under-5 (per 1,000 live births)', 'Continent'], axis=1)
Merged_data_2.head()
# Out:
#         Entity Code  Year  Number of under-five deaths  \
# 0  Afghanistan  AFG  1965                       159930
# 1  Afghanistan  AFG  1966                       160878
# 2  Afghanistan  AFG  1967                       161784
# 3  Afghanistan  AFG  1968                       162828
# 4  Afghanistan  AFG  1969                       163784
#
#    Estimates, 1950 - 2020: Total population by broad age group, both sexes combined (thousands) - Total  \
# 0                                           9956.318
# 1                                          10174.840
# 2                                          10399.936
# 3                                          10637.064
# 4                                          10893.772
#
#    Estimates, 1950 - 2020: Annually interpolated demographic indicators - Under-five mortality (deaths under age 5 per 1,000 live births)
# 0                                            32.8027
# 1                                            32.2593
# ...

# %%
Merged_data_2.rename(columns={'Entity': 'Country', 'Estimates, 1950 - 2020: Total population by broad age group, both sexes combined (thousands) - Total': 'Total population (thousands)', 'Estimates, 1950 - 2020: Annually interpolated demographic indicators - Under-five mortality (deaths under age 5 per 1,000 live births)': 'Mortality rate, under-5 (per 1,000 live births)'}, inplace=True)
Merged_data_2.head()
# Out:
#        Country Code  Year  Number of under-five deaths  \
# 0  Afghanistan  AFG  1965                       159930
# 1  Afghanistan  AFG  1966                       160878
# 2  Afghanistan  AFG  1967                       161784
# 3  Afghanistan  AFG  1968                       162828
# 4  Afghanistan  AFG  1969                       163784
#
#    Total population (thousands)  \
# 0                      9956.318
# 1                     10174.840
# 2                     10399.936
# 3                     10637.064
# 4                     10893.772
#
#    Mortality rate, under-5 (per 1,000 live births)
# 0                                          32.8027
# 1                                          32.2593
# 2                                          31.7215
# 3                                          31.1823
# 4                                          30.6375
